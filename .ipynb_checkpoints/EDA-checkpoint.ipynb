# %% [markdown]
# ## EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
#
#      Headquarters                    Size  Founded   Type of ownership  ...  \
# 0      Goleta, CA   501 to 1000 employees     1973   Company - Private  ...
# 1   Baltimore, MD        10000+ employees     1984  Other Organization  ...
# 2  Clearwater, FL   501 to 1000 employees     2010   Company - Private  ...
# 3    Richland, WA  1001 to 5000 employees     1965          Government  ...
# 4    New York, NY     51 to 200 employees     1998   Company - Private  ...
#
#   average_salary                              company_txt job_state  \
# 0           72.0                      Tecolote Research\n        NM
# 1           87.5  University of Maryland Medical System\n        MD
# 2           85.0                                KnowBe4\n        FL
# 3           76.5                                   PNNL\n        WA
# 4          114.5                     Affinity Solutions\n        NY
#
#   same_state  age  python_yn  R_yn  spark_yn  excel_yn aws_yn
# 0          0   48          1     0         0         1      0
# 1          0   37          1     0         0         0      0
# 2          1   11          1     0         1         1      0
# 3          1   56          1     0         0         0      0
# 4          1   23          1     0         0         1      0
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'company_txt', 'job_state', 'same_state', 'age',
#        'python_yn', 'R_yn', 'spark_yn', 'excel_yn', 'aws_yn'],
#       dtype='object')

# %% [markdown]
# ## Title simplifier and seniority classification

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'machine learning'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principle' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'junior' in title.lower() or 'jr.' in title.lower():
        return 'junior'
    else:
        return 'na'

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df['job_simp'].value_counts()
# Out:
# data scientist      279
# na                  184
# data engineer       119
# analyst             102
# manager              22
# machine learning     22
# director             14
# Name: job_simp, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)

# %%
df.seniority.value_counts()
# Out:
# na        544
# senior    195
# junior      3
# Name: seniority, dtype: int64

# %% [markdown]
# ## fix Los Angeles

# %%
df['job_state'] = df.job_state.apply(lambda x: x.strip() if x.strip().lower()!= 'los angeles' else 'CA' )

# %%
df.job_state.value_counts()
# Out:
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# WA     21
# NC     21
# NJ     17
# FL     16
# OH     14
# TN     13
# CO     11
# DC     11
# WI     10
# UT     10
# IN     10
# MO      9
# AZ      9
# AL      8
# GA      6
# MI      6
# KY      6
# DE      6
# CT      5
# IA      5
# OR      4
# NE      4
# LA      4
# NM      3
# KS      3
# MN      2
# ID      2
# SC      1
# RI      1
# Name: job_state, dtype: int64

# %% [markdown]
# ## job description length

# %%
df['job_desc_len'] = df['Job Description'].apply(lambda x: len(x))

# %%
df['job_desc_len']
# Out:
# 0      2536
# 1      4783
# 2      3461
# 3      3883
# 4      2728
#        ...
# 737    6162
# 738    6130
# 739    3078
# 740    1642
# 741    3673
# Name: job_desc_len, Length: 742, dtype: int64

# %% [markdown]
# ## Compitetor count

# %%
df['num_comp'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)

# %%
df.num_comp.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    3
# 4    3
# Name: num_comp, dtype: int64

# %%
df['Competitors']
# Out:
# 0                                                     -1
# 1                                                     -1
# 2                                                     -1
# 3      Oak Ridge National Laboratory, National Renewa...
# 4                   Commerce Signals, Cardlytics, Yodlee
#                              ...
# 737                           Pfizer, AstraZeneca, Merck
# 738                      See Tickets, TicketWeb, Vendini
# 739                                                   -1
# 740                                                   -1
# 741                                                   -1
# Name: Competitors, Length: 742, dtype: object

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'company_txt', 'job_state', 'same_state', 'age',
#        'python_yn', 'R_yn', 'spark_yn', 'excel_yn', 'aws_yn', 'job_simp',
#        'seniority', 'job_desc_len', 'num_comp'],
#       dtype='object')

# %% [markdown]
# ## convert hourly salary to annual

# %%
df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly == 1 else x.min_salary, axis=1)

# %%
df['min_salary'].head()
# Out:
# 0    53
# 1    63
# 2    80
# 3    56
# 4    86
# Name: min_salary, dtype: int64

# %%
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly == 1 else x.max_salary, axis=1)

# %%
df[df.hourly == 1][['hourly','min_salary','max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 165       1          34          48
# 177       1          42          68
# 197       1          36          50
# 202       1          42          68
# 210       1          30          50
# 246       1          34          48
# 271       1          42          68
# 337       1          36          50
# 345       1          48          78
# 357       1          42          68
# 363       1          50          56
# 408       1          42          58
# 409       1          20          34
# 492       1          36          50
# 509       1          48          78
# 533       1          42          68
# 542       1          50          56
# 617       1          42          58
# 618       1          20          34
# 645       1          54          94
# 666       1          36          50
# 682       1          48          78
# 711       1          42          68
# 724       1          50          56

# %%
df['company_txt'] = df.company_txt.apply(lambda x: x.replace('\n',''))

# %%
df.company_txt
# Out:
# 0                          Tecolote Research
# 1      University of Maryland Medical System
# 2                                    KnowBe4
# 3                                       PNNL
# 4                         Affinity Solutions
#                        ...
# 737                                      GSK
# 738                               Eventbrite
# 739           Software Engineering Institute
# 740                             Numeric, LLC
# 741             Riverside Research Institute
# Name: company_txt, Length: 742, dtype: object

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.719677
# std      0.801210   497.183763    0.177034           0.149721   30.980593
# min     -1.000000    -1.000000    0.000000           0.000000   15.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  average_salary  same_state         age   python_yn  \
# count  742.000000      742.000000  742.000000  742.000000  742.000000
# mean   128.149596      100.626011    0.557951   47.524259    0.528302
# std     45.220324       38.855948    0.496965   53.839080    0.499535
# min     16.000000       13.500000    0.000000   -1.000000    0.000000
# 25%     96.000000       73.500000    0.000000   12.000000    0.000000
# 50%    124.000000       97.500000    1.000000   25.000000    1.000000
# 75%    155.000000      122.500000    1.000000   60.000000    1.000000
# max    306.000000      254.000000    1.000000  277.000000    1.000000
#
#              R_yn    spark_yn    excel_yn      aws_yn  job_desc_len  \
# count  742.000000  742.000000  742.000000  742.000000    742.000000
# mean     0.002695    0.225067    0.522911    0.237197   3869.545822
# std      0.051882    0.417908    0.499812    0.425651   1521.495868
# min      0.000000    0.000000    0.000000    0.000000    407.000000
# 25%      0.000000    0.000000    0.000000    0.000000   2801.000000
# 50%      0.000000    0.000000    1.000000    0.000000   3731.000000
# 75%      0.000000    0.000000    1.000000    0.000000   4740.000000
# max      1.000000    1.000000    1.000000    1.000000  10051.000000
#
#          num_comp
# count  742.000000
# mean     1.053908
# std      1.384239
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      3.000000
# max      4.000000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'company_txt', 'job_state', 'same_state', 'age',
#        'python_yn', 'R_yn', 'spark_yn', 'excel_yn', 'aws_yn', 'job_simp',
#        'seniority', 'job_desc_len', 'num_comp'],
#       dtype='object')

# %%
# histogram of Rating
sns.histplot(df['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Count'>

# %%
# histogram of average salary
sns.histplot(df['average_salary'])
# Out:
# <AxesSubplot:xlabel='average_salary', ylabel='Count'>

# %%
# hist of min salary
sns.histplot(df['min_salary'])
# Out:
# <AxesSubplot:xlabel='min_salary', ylabel='Count'>

# %%
# hist of max salary
sns.histplot(df['max_salary'])
# Out:
# <AxesSubplot:xlabel='max_salary', ylabel='Count'>

# %%
#age
sns.histplot(df['age'])
# as the age is not normally distributed we cannot use is for regular regression 
# so in future we might need to normalize the data
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
# description length
sns.histplot(df['job_desc_len'])
# Out:
# <AxesSubplot:xlabel='job_desc_len', ylabel='Count'>

# %%
df.boxplot(column=['age','average_salary','Rating'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['Rating'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['average_salary'])
# Out:
# <AxesSubplot:>

# %%
df[['age','average_salary','Rating','job_desc_len']].corr()
# Out:
#                      age  average_salary    Rating  job_desc_len
# age             1.000000        0.019574  0.023162      0.164188
# average_salary  0.019574        1.000000  0.013492      0.078808
# Rating          0.023162        0.013492  1.000000     -0.012281
# job_desc_len    0.164188        0.078808 -0.012281      1.000000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'company_txt', 'job_state', 'same_state', 'age',
#        'python_yn', 'R_yn', 'spark_yn', 'excel_yn', 'aws_yn', 'job_simp',
#        'seniority', 'job_desc_len', 'num_comp'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Headquarters', 'Size', 'Type of ownership','Industry','Sector','Revenue','company_txt','job_state','same_state','python_yn', 'R_yn', 'spark_yn', 'excel_yn', 'aws_yn', 'job_simp',
       'seniority']]

# %%
for i in df_cat.columns:
    plt.figure(figsize=(13,6))
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y = cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 200
# graph for Headquarters: total = 198
# graph for Size: total = 9
# graph for Type of ownership: total = 11
# graph for Industry: total = 60
# graph for Sector: total = 25
# graph for Revenue: total = 14
# graph for company_txt: total = 343
# graph for job_state: total = 37
# graph for same_state: total = 2
# graph for python_yn: total = 2
# graph for R_yn: total = 2
# graph for spark_yn: total = 2
# graph for excel_yn: total = 2
# graph for aws_yn: total = 2
# graph for job_simp: total = 7
# graph for seniority: total = 3

# %%
for i in df_cat[['Location','Headquarters','company_txt']].columns:
    plt.figure(figsize=(13,6))
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y = cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for company_txt: total = 20

# %%
# make a pivot table to comare the cateregorical data with neumerical

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'company_txt', 'job_state', 'same_state', 'age',
#        'python_yn', 'R_yn', 'spark_yn', 'excel_yn', 'aws_yn', 'job_simp',
#        'seniority', 'job_desc_len', 'num_comp'],
#       dtype='object')

# %%
pd.pivot_table(df, index=['job_simp','seniority'],values='average_salary')
# Out:
#                             average_salary
# job_simp         seniority
# analyst          junior          53.250000
#                  na              61.308219
#                  senior          79.092593
# data engineer    na              97.493976
#                  senior         123.638889
# data scientist   junior         106.500000
#                  na             110.525510
#                  senior         134.524390
# director         na             168.607143
# machine learning na             126.218750
#                  senior         127.000000
# manager          na              84.022727
# na               na              76.885714
#                  senior         110.204545

# %%
pd.set_option('display.max_rows', None)
pd.pivot_table(df, index=['job_state','job_simp'],values='average_salary').sort_values('job_state',ascending=False)
# Out:
#                             average_salary
# job_state job_simp
# WI        na                     54.000000
#           data scientist        113.500000
#           analyst                58.833333
# WA        na                     97.500000
#           data scientist         99.764706
#           analyst                54.500000
# VA        na                     79.300000
#           machine learning       87.000000
#           data scientist        108.416667
#           data engineer          96.900000
#           analyst                71.583333
# UT        data engineer         100.333333
#           analyst                54.750000
#           data scientist        140.500000
# TX        na                     41.285714
#           data scientist        100.730769
#           data engineer         113.062500
# TN        data scientist         96.000000
#           data engineer         100.950000
#           analyst                13.500000
# SC        na                     60.500000
# RI        analyst               100.000000
# PA        machine learning      120.500000
#           data engineer          91.500000
#           data scientist        113.333333
#           analyst                62.750000
#           manager               109.666667
#           na                     76.062500
# OR        data scientist         98.500000
#           data engineer          73.000000
# OH        na                     91.166667
#           data scientist        105.285714
#           analyst                53.875000
# NY        na                     81.583333
#           machine learning      125.000000
#           data scientist        115.250000
#           data engineer          86.375000
#           analyst                65.607143
# NM        data scientist         74.333333
# NJ        data scientist        106.875000
#           analyst                83.583333
#           data engineer         112.000000
#           manager               109.500000
#           director              161.500000
#           na                     82.500000
# NE        na                     41.000000
# NC        na                     90.916667
#           data scientist        117.000000
#           data engineer         104.250000
# MO        na                     72.333333
#           manager                40.500000
#           data scientist        127.666667
#           analyst                61.000000
# MN        data engineer          95.000000
#           analyst                76.000000
# MI        manager                87.500000
#           data scientist        106.625000
# MD        na                     88.750000
#           data scientist        109.115385
#           data engineer         109.000000
#           analyst                80.666667
# MA        na                    107.478261
#           manager                71.900000
#           director              117.833333
#           data scientist        113.750000
#           data engineer         107.291667
#           analyst                59.125000
# LA        analyst                48.000000
#           data engineer          70.500000
#           na                     20.000000
# KY        na                    103.500000
#           data scientist         84.000000
# KS        machine learning       87.000000
# IN        na                     69.000000
#           data scientist         84.500000
#           data engineer         114.500000
# IL        analyst                66.500000
#           na                     57.166667
#           machine learning      133.000000
#           director              221.750000
#           data scientist        117.233333
#           data engineer          96.125000
# ID        analyst                56.250000
# IA        analyst                43.000000
#           data engineer         102.833333
# GA        data scientist         81.333333
#           na                     80.000000
# FL        data scientist         97.357143
#           data engineer          91.833333
#           analyst                47.500000
# DE        na                     27.500000
# DC        data scientist        149.000000
#           data engineer          85.000000
#           analyst                63.500000
# CT        na                     62.500000
#           data scientist         84.000000
# CO        machine learning      100.500000
#           data engineer          99.000000
#           analyst                29.500000
#           na                     31.500000
#           data scientist        108.666667
# CA        na                     99.907407
#           manager                80.611111
#           machine learning      177.300000
#           data scientist        142.522059
#           data engineer         129.540000
#           analyst                85.250000
# AZ        data scientist         69.500000
#           data engineer          79.500000
#           analyst                55.000000
#           na                    124.500000
# AL        na                     43.750000
#           data engineer          65.000000
#           analyst                62.200000

# %%
pd.pivot_table(df[df.job_simp == 'data scientist'],index='job_state',values='average_salary').sort_values('average_salary',ascending=False)
# Out:
#            average_salary
# job_state
# DC             149.000000
# CA             142.522059
# UT             140.500000
# MO             127.666667
# IL             117.233333
# NC             117.000000
# NY             115.250000
# MA             113.750000
# WI             113.500000
# PA             113.333333
# MD             109.115385
# CO             108.666667
# VA             108.416667
# NJ             106.875000
# MI             106.625000
# OH             105.285714
# TX             100.730769
# WA              99.764706
# OR              98.500000
# FL              97.357143
# TN              96.000000
# IN              84.500000
# KY              84.000000
# CT              84.000000
# GA              81.333333
# NM              74.333333
# AZ              69.500000

# %%
#salary vs rating

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'company_txt', 'job_state', 'same_state', 'age',
#        'python_yn', 'R_yn', 'spark_yn', 'excel_yn', 'aws_yn', 'job_simp',
#        'seniority', 'job_desc_len', 'num_comp'],
#       dtype='object')

# %%
df_pivots = df[['Rating','Industry','Sector','Revenue','num_comp','hourly','employer_provided','python_yn','R_yn','spark_yn','excel_yn','aws_yn','Type of ownership','average_salary']]

# %%
df_pivots.head(5)
# Out:
#    Rating                          Industry                        Sector  \
# 0     3.8               Aerospace & Defense           Aerospace & Defense
# 1     3.4  Health Care Services & Hospitals                   Health Care
# 2     4.8                 Security Services             Business Services
# 3     3.8                            Energy  Oil, Gas, Energy & Utilities
# 4     2.9           Advertising & Marketing             Business Services
#
#                             Revenue  num_comp  hourly  employer_provided  \
# 0         $50 to $100 million (USD)         0       0                  0
# 1            $2 to $5 billion (USD)         0       0                  0
# 2        $100 to $500 million (USD)         0       0                  0
# 3  $500 million to $1 billion (USD)         3       0                  0
# 4          Unknown / Non-Applicable         3       0                  0
#
#    python_yn  R_yn  spark_yn  excel_yn  aws_yn   Type of ownership  \
# 0          1     0         0         1       0   Company - Private
# 1          1     0         0         0       0  Other Organization
# 2          1     0         1         1       0   Company - Private
# 3          1     0         0         0       0          Government
# 4          1     0         0         1       0   Company - Private
#
#    average_salary
# 0            72.0
# 1            87.5
# 2            85.0
# 3            76.5
# 4           114.5

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots,index=i,values='average_salary').sort_values('average_salary',ascending=False))
    print('\n')
# Out:
# Rating
#         average_salary
# Rating
# -1.0        136.181818
#  5.0        134.700000
#  2.5        120.000000
#  4.5        117.714286
#  4.1        116.368421
#  3.9        113.071429
#  2.6        109.083333
#  4.4        108.606061
#  3.2        105.500000
#  4.0        105.340426
#  3.5        104.897959
#  3.7        104.131148
#  4.7        103.983871
#  4.3        102.468750
#  3.3        101.858974
#  4.2        100.442308
#  2.2         97.750000
#  4.6         97.250000
#  3.8         96.811475
#  2.1         95.900000
#  3.4         93.011364
#  1.9         87.500000
#  3.1         86.580000
#  3.0         85.588235
#  3.6         85.467391
#  2.8         83.928571
#  2.7         83.250000
#  2.3         81.500000
#  2.9         81.138889
#  4.8         80.277778
#  2.4         60.214286
#
#
# Industry
#                                           average_salary
# Industry
# Other Retail Stores                           163.500000
# Motion Picture Production & Distribution      146.000000
# Financial Analytics & Research                145.125000
# Health, Beauty, & Fitness                     139.500000
# Telecommunications Services                   131.500000
# Brokerage Services                            129.000000
# Auctions & Galleries                          128.000000
# Internet                                      123.810345
# Investment Banking & Asset Management         118.400000
# TV Broadcast & Cable Networks                 117.750000
# Enterprise Software & Network Solutions       115.369048
# Computer Hardware & Software                  115.194915
# -1                                            114.650000
# Accounting                                    113.500000
# Biotech & Pharmaceuticals                     111.767857
# Insurance Agencies & Brokerages               109.250000
# K-12 Education                                108.875000
# Consulting                                    108.689655
# Transportation Management                     107.500000
# Metals Brokers                                107.000000
# Staffing & Outsourcing                        106.200000
# Video Games                                   106.166667
# Insurance Carriers                            105.626984
# Real Estate                                   104.750000
# Transportation Equipment Manufacturing        104.500000
# Advertising & Marketing                       104.300000
# Wholesale                                     103.166667
# IT Services                                   102.840000
# Colleges & Universities                       102.687500
# Aerospace & Defense                            99.060000
# Logistics & Supply Chain                       98.250000
# Gas Stations                                   98.000000
# Mining                                         98.000000
# Consumer Products Manufacturing                95.350000
# Security Services                              93.500000
# Department, Clothing, & Shoe Stores            92.666667
# Stock Exchanges                                87.000000
# Industrial Manufacturing                       86.750000
# Consumer Product Rental                        86.666667
# Beauty & Personal Accessories Stores           85.500000
# Sporting Goods Stores                          85.000000
# Lending                                        83.000000
# Farm Support Services                          80.500000
# Energy                                         80.464286
# Education Training Services                    79.500000
# Trucking                                       79.000000
# Religious Organizations                        78.833333
# Federal Agencies                               78.545455
# Research & Development                         78.394737
# Financial Transaction Processing               76.500000
# Health Care Products Manufacturing             73.000000
# Banks & Credit Unions                          70.625000
# Travel Agencies                                69.500000
# Health Care Services & Hospitals               67.622449
# Food & Beverage Manufacturing                  53.250000
# Architectural & Engineering Services           50.500000
# Gambling                                       48.500000
# Social Assistance                              48.166667
# Telecommunications Manufacturing               44.000000
# Construction                                   26.500000
#
#
# Sector
#                                     average_salary
# Sector
# Media                                   116.666667
# -1                                      114.650000
# Accounting & Legal                      113.500000
# Information Technology                  113.191667
# Biotech & Pharmaceuticals               111.767857
# Insurance                               105.942029
# Real Estate                             104.750000
# Mining & Metals                         104.000000
# Telecommunications                      102.333333
# Education                               100.739130
# Consumer Services                        99.875000
# Retail                                   99.666667
# Transportation & Logistics               99.312500
# Aerospace & Defense                      99.060000
# Business Services                        97.701031
# Finance                                  97.369048
# Manufacturing                            84.044118
# Agriculture & Forestry                   80.500000
# Oil, Gas, Energy & Utilities             80.464286
# Government                               78.545455
# Travel & Tourism                         69.500000
# Non-Profit                               68.611111
# Health Care                              67.622449
# Arts, Entertainment & Recreation         48.500000
# Construction, Repair & Maintenance       26.500000
#
#
# Revenue
#                                   average_salary
# Revenue
# $5 to $10 million (USD)               126.111111
# $1 to $5 million (USD)                119.312500
# -1                                    117.500000
# $10+ billion (USD)                    115.165323
# Less than $1 million (USD)            108.625000
# $1 to $2 billion (USD)                104.533333
# Unknown / Non-Applicable              104.310345
# $50 to $100 million (USD)             100.565217
# $10 to $25 million (USD)              100.359375
# $2 to $5 billion (USD)                 94.730769
# $5 to $10 billion (USD)                94.184211
# $500 million to $1 billion (USD)       86.991228
# $100 to $500 million (USD)             83.153846
# $25 to $50 million (USD)               82.837500
#
#
# num_comp
#           average_salary
# num_comp
# 2             106.865854
# 1             106.208333
# 3             105.504386
# 0              97.602174
# 4              56.500000
#
#
# hourly
#         average_salary
# hourly
# 0             103.1539
# 1              25.0000
#
#
# employer_provided
#                    average_salary
# employer_provided
# 1                      119.970588
# 0                      100.172414
#
#
# python_yn
#            average_salary
# python_yn
# 1              112.653061
# 0               87.155714
#
#
# R_yn
#       average_salary
# R_yn
# 0         100.706757
# 1          70.750000
#
#
# spark_yn
#           average_salary
# spark_yn
# 1             113.347305
# 0              96.931304
#
#
# excel_yn
#           average_salary
# excel_yn
# 0             102.953390
# 1              98.502577
#
#
# aws_yn
#         average_salary
# aws_yn
# 1           112.559659
# 0            96.915194
#
#
# Type of ownership
#                                 average_salary
# Type of ownership
# -1                                  117.500000
# Company - Public                    110.893782
# Subsidiary or Business Segment      110.573529
# College / University                107.615385
# Company - Private                   101.776829
# Government                           84.300000
# School / School District             77.750000
# Other Organization                   77.500000
# Nonprofit Organization               68.281818
# Hospital                             54.000000
# Unknown                              39.500000
#
#
# average_salary
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-87759343346c> in <module>
#       1 for i in df_pivots.columns:
#       2     print(i)
# ----> 3     print(pd.pivot_table(df_pivots,index=i,values='average_salary').sort_values('average_salary',ascending=False))
#       4     print('\n')
#
# ~/Documents/data Science/glassdoor_ds/env/lib/python3.9/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#     110         values = list(values)
#     111
# --> 112     grouped = data.groupby(keys, observed=observed)
#     113     agged = grouped.agg(aggfunc)
#     114     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# ~/Documents/data Science/glassdoor_ds/env/lib/python3.9/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~/Documents/data Science/glassdoor_ds/env/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ~/Documents/data Science/glassdoor_ds/env/lib/python3.9/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     826         # allow us to passing the actual Grouping as the gpr
#     827         ping = (
# --> 828             Grouping(
#     829                 group_axis,
#     830                 gpr,
#
# ~/Documents/data Science/glassdoor_ds/env/lib/python3.9/site-packages/pandas/core/groupby/grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis, dropna)
#     541                 if getattr(self.grouper, "ndim", 1) != 1:
#     542                     t = self.name or str(type(self.grouper))
# --> 543                     raise ValueError(f"Grouper for '{t}' not 1-dimensional")
#     544                 self.grouper = self.index.map(self.grouper)
#     545                 if not (
#
# ValueError: Grouper for 'average_salary' not 1-dimensional

# %%
#pivot for revenue X python 
pd.pivot_table(df_pivots, index='Revenue', columns='python_yn', values='average_salary', aggfunc='count')
# Out:
# python_yn                            0      1
# Revenue
# $1 to $2 billion (USD)            16.0   44.0
# $1 to $5 million (USD)             1.0    7.0
# $10 to $25 million (USD)          16.0   16.0
# $10+ billion (USD)                66.0   58.0
# $100 to $500 million (USD)        47.0   44.0
# $2 to $5 billion (USD)            17.0   22.0
# $25 to $50 million (USD)          24.0   16.0
# $5 to $10 billion (USD)            9.0   10.0
# $5 to $10 million (USD)            9.0    9.0
# $50 to $100 million (USD)         21.0   25.0
# $500 million to $1 billion (USD)  29.0   28.0
# -1                                 1.0    NaN
# Less than $1 million (USD)         1.0    3.0
# Unknown / Non-Applicable          93.0  110.0

# %%
#example of the use of columns
pd.pivot_table(df_pivots, index='Revenue', columns='Sector', values='average_salary', aggfunc='count')
# Out:
# Sector                             -1  Accounting & Legal  \
# Revenue
# $1 to $2 billion (USD)            NaN                 NaN
# $1 to $5 million (USD)            NaN                 NaN
# $10 to $25 million (USD)          NaN                 NaN
# $10+ billion (USD)                NaN                 NaN
# $100 to $500 million (USD)        NaN                 NaN
# $2 to $5 billion (USD)            NaN                 NaN
# $25 to $50 million (USD)          NaN                 NaN
# $5 to $10 billion (USD)           NaN                 NaN
# $5 to $10 million (USD)           NaN                 NaN
# $50 to $100 million (USD)         NaN                 NaN
# $500 million to $1 billion (USD)  NaN                 NaN
# -1                                1.0                 NaN
# Less than $1 million (USD)        1.0                 1.0
# Unknown / Non-Applicable          8.0                 NaN
#
# Sector                            Aerospace & Defense  Agriculture & Forestry  \
# Revenue
# $1 to $2 billion (USD)                            3.0                     NaN
# $1 to $5 million (USD)                            NaN                     NaN
# $10 to $25 million (USD)                          1.0                     NaN
# $10+ billion (USD)                                9.0                     NaN
# $100 to $500 million (USD)                        6.0                     NaN
# $2 to $5 billion (USD)                            1.0                     NaN
# $25 to $50 million (USD)                          2.0                     NaN
# $5 to $10 billion (USD)                           NaN                     NaN
# $5 to $10 million (USD)                           NaN                     NaN
# $50 to $100 million (USD)                         1.0                     1.0
# $500 million to $1 billion (USD)                  1.0                     NaN
# -1                                                NaN                     NaN
# Less than $1 million (USD)                        NaN                     NaN
# Unknown / Non-Applicable                          1.0                     NaN
#
# Sector                            Arts, Entertainment & Recreation  \
# Revenue
# $1 to $2 billion (USD)                                         NaN
# $1 to $5 million (USD)                                         NaN
# $10 to $25 million (USD)                                       NaN
# $10+ billion (USD)                                             NaN
# $100 to $500 million (USD)                                     4.0
# $2 to $5 billion (USD)                                         NaN
# $25 to $50 million (USD)                                       NaN
# $5 to $10 billion (USD)                                        NaN
# $5 to $10 million (USD)                                        NaN
# $50 to $100 million (USD)                                      NaN
# $500 million to $1 billion (USD)                               NaN
# -1                                                             NaN
# Less than $1 million (USD)                                     NaN
# Unknown / Non-Applicable                                       NaN
#
# Sector                            Biotech & Pharmaceuticals  \
# Revenue
# $1 to $2 billion (USD)                                  9.0
# $1 to $5 million (USD)                                  5.0
# $10 to $25 million (USD)                                2.0
# $10+ billion (USD)                                     45.0
# $100 to $500 million (USD)                              9.0
# $2 to $5 billion (USD)                                  2.0
# $25 to $50 million (USD)                               10.0
# $5 to $10 billion (USD)                                 NaN
# $5 to $10 million (USD)                                 NaN
# $50 to $100 million (USD)                               6.0
# $500 million to $1 billion (USD)                        1.0
# -1                                                      NaN
# Less than $1 million (USD)                              NaN
# Unknown / Non-Applicable                               23.0
#
# Sector                            Business Services  \
# Revenue
# $1 to $2 billion (USD)                          7.0
# $1 to $5 million (USD)                          2.0
# $10 to $25 million (USD)                        9.0
# $10+ billion (USD)                              1.0
# $100 to $500 million (USD)                     12.0
# $2 to $5 billion (USD)                          3.0
# $25 to $50 million (USD)                       11.0
# $5 to $10 billion (USD)                         NaN
# $5 to $10 million (USD)                        10.0
# $50 to $100 million (USD)                      10.0
# $500 million to $1 billion (USD)                5.0
# -1                                              NaN
# Less than $1 million (USD)                      NaN
# Unknown / Non-Applicable                       27.0
#
# Sector                            Construction, Repair & Maintenance  \
# Revenue
# $1 to $2 billion (USD)                                           NaN
# $1 to $5 million (USD)                                           NaN
# $10 to $25 million (USD)                                         NaN
# $10+ billion (USD)                                               NaN
# $100 to $500 million (USD)                                       NaN
# $2 to $5 billion (USD)                                           NaN
# $25 to $50 million (USD)                                         NaN
# $5 to $10 billion (USD)                                          NaN
# $5 to $10 million (USD)                                          NaN
# $50 to $100 million (USD)                                        NaN
# $500 million to $1 billion (USD)                                 NaN
# -1                                                               NaN
# Less than $1 million (USD)                                       NaN
# Unknown / Non-Applicable                                         3.0
#
# Sector                            Consumer Services  Education  ...  \
# Revenue                                                         ...
# $1 to $2 billion (USD)                          NaN        NaN  ...
# $1 to $5 million (USD)                          NaN        NaN  ...
# $10 to $25 million (USD)                        NaN        NaN  ...
# $10+ billion (USD)                              NaN        NaN  ...
# $100 to $500 million (USD)                      NaN        1.0  ...
# $2 to $5 billion (USD)                          NaN        NaN  ...
# $25 to $50 million (USD)                        NaN        2.0  ...
# $5 to $10 billion (USD)                         NaN        NaN  ...
# $5 to $10 million (USD)                         1.0        1.0  ...
# $50 to $100 million (USD)                       NaN        NaN  ...
# $500 million to $1 billion (USD)                NaN        NaN  ...
# -1                                              NaN        NaN  ...
# Less than $1 million (USD)                      NaN        NaN  ...
# Unknown / Non-Applicable                        3.0       19.0  ...
#
# Sector                            Manufacturing  Media  Mining & Metals  \
# Revenue
# $1 to $2 billion (USD)                      2.0    NaN              1.0
# $1 to $5 million (USD)                      NaN    NaN              NaN
# $10 to $25 million (USD)                    NaN    NaN              NaN
# $10+ billion (USD)                         16.0    3.0              NaN
# $100 to $500 million (USD)                  5.0    NaN              NaN
# $2 to $5 billion (USD)                      4.0    NaN              NaN
# $25 to $50 million (USD)                    1.0    NaN              NaN
# $5 to $10 billion (USD)                     1.0    NaN              NaN
# $5 to $10 million (USD)                     NaN    NaN              NaN
# $50 to $100 million (USD)                   NaN    NaN              NaN
# $500 million to $1 billion (USD)            1.0    2.0              NaN
# -1                                          NaN    NaN              NaN
# Less than $1 million (USD)                  NaN    NaN              NaN
# Unknown / Non-Applicable                    4.0    1.0              2.0
#
# Sector                            Non-Profit  Oil, Gas, Energy & Utilities  \
# Revenue
# $1 to $2 billion (USD)                   NaN                           2.0
# $1 to $5 million (USD)                   NaN                           NaN
# $10 to $25 million (USD)                 NaN                           NaN
# $10+ billion (USD)                       NaN                           NaN
# $100 to $500 million (USD)               NaN                           NaN
# $2 to $5 billion (USD)                   NaN                           NaN
# $25 to $50 million (USD)                 1.0                           NaN
# $5 to $10 billion (USD)                  NaN                           NaN
# $5 to $10 million (USD)                  NaN                           NaN
# $50 to $100 million (USD)                1.0                           NaN
# $500 million to $1 billion (USD)         NaN                          12.0
# -1                                       NaN                           NaN
# Less than $1 million (USD)               NaN                           NaN
# Unknown / Non-Applicable                 7.0                           NaN
#
# Sector                            Real Estate  Retail  Telecommunications  \
# Revenue
# $1 to $2 billion (USD)                    2.0     1.0                 NaN
# $1 to $5 million (USD)                    NaN     NaN                 NaN
# $10 to $25 million (USD)                  NaN     NaN                 NaN
# $10+ billion (USD)                        NaN     6.0                 NaN
# $100 to $500 million (USD)                NaN     4.0                 NaN
# $2 to $5 billion (USD)                    3.0     NaN                 4.0
# $25 to $50 million (USD)                  NaN     NaN                 NaN
# $5 to $10 billion (USD)                   NaN     2.0                 NaN
# $5 to $10 million (USD)                   NaN     NaN                 NaN
# $50 to $100 million (USD)                 NaN     NaN                 2.0
# $500 million to $1 billion (USD)          2.0     1.0                 NaN
# -1                                        NaN     NaN                 NaN
# Less than $1 million (USD)                NaN     NaN                 NaN
# Unknown / Non-Applicable                  1.0     1.0                 NaN
#
# Sector                            Transportation & Logistics  Travel & Tourism
# Revenue
# $1 to $2 billion (USD)                                   NaN               NaN
# $1 to $5 million (USD)                                   NaN               NaN
# $10 to $25 million (USD)                                 2.0               NaN
# $10+ billion (USD)                                       NaN               NaN
# $100 to $500 million (USD)                               NaN               NaN
# $2 to $5 billion (USD)                                   3.0               7.0
# $25 to $50 million (USD)                                 NaN               NaN
# $5 to $10 billion (USD)                                  NaN               NaN
# $5 to $10 million (USD)                                  NaN               NaN
# $50 to $100 million (USD)                                NaN               NaN
# $500 million to $1 billion (USD)                         NaN               NaN
# -1                                                       NaN               NaN
# Less than $1 million (USD)                               NaN               NaN
# Unknown / Non-Applicable                                 3.0               1.0
#
# [14 rows x 25 columns]

# %%
# just for fun

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# code for nltk if not working or showing error
import nltk
# import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download('stopwords')
nltk.download('punkt')
# punkt
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/vaishnavbharadwaj/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/vaishnavbharadwaj/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    filetered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filetered.append(w.lower())
    return filetered

words_fileterd = punctuation_stop(words)

text = " ".join([ele for ele in words_fileterd])

wc = WordCloud(background_color="white", random_state=1, stopwords=STOPWORDS, max_words=2000, width=800, height=1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()
